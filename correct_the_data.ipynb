# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Create a sample dataframe
original_data = pd.read_csv('/content/drive/MyDrive/NewFairML/data/.csv',dtype=object)
#df = pd.DataFrame({'year': ['2010', '2011', '2012', '2020', '2021']})
df = original_data

# Define the desired values
valid_years = ["2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-d269f2cd5c4f> in <module>
#       2
#       3 # Create a sample dataframe
# ----> 4 original_data = pd.read_csv('/content/drive/MyDrive/NewFairML/data/.csv',dtype=object)
#       5 #df = pd.DataFrame({'year': ['2010', '2011', '2012', '2020', '2021']})
#       6 df = original_data
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df = original_data

# %%
# Use the `~` operator to negate the condition
#df = df[~df['General Data year'].isin(valid_years)]

# Drop rows that do not match the desired values
df = df.loc[df['General Data year'].isin(valid_years)]

# %%
original_data["General Data year"].value_counts()
# Out:
# 2019    71126
# 2017    70692
# 2018    67846
# 2016    63936
# 2015    52618
# 2014    47195
# 2013    44110
# 2012    41622
# 2011    41459
# 2010    38401
# Name: General Data year, dtype: int64

# %%
df["General Data year"].value_counts()
# Out:
# 2019    71126
# 2017    70692
# 2018    67846
# 2016    63936
# 2015    52618
# 2014    47195
# 2013    44110
# 2012    41622
# 2011    41459
# 2010    38401
# Name: General Data year, dtype: int64

# %%
df.to_csv('/content/drive/My Drive/USAll.csv', index=False)

# %%
df.head(5)
# Out:
#   General Record Type General Resident status  \
# 0                   2                       2
# 1                   1                       1
# 2                   1                       1
# 3                   1                       1
# 4                   1                       1
#
#   General Place of death and decedents status General Day of week of death  \
# 0                                           6                            6
# 1                                           4                            1
# 2                                           4                            1
# 3                                           4                            6
# 4                                           4                            7
#
#   General Data year General Manner of death Occurrence State(FIPS)  \
# 0              2010                       7                     AK
# 1              2010                       7                     AK
# ...

# %%
original_data.head(5)
# Out:
#   General Record Type General Resident status  \
# 0                   2                       2
# 1                   1                       1
# 2                   1                       1
# 3                   1                       1
# 4                   1                       1
#
#   General Place of death and decedents status General Day of week of death  \
# 0                                           6                            6
# 1                                           4                            1
# 2                                           4                            1
# 3                                           4                            6
# 4                                           4                            7
#
#   General Data year General Manner of death Occurrence State(FIPS)  \
# 0              2010                       7                     AK
# 1              2010                       7                     AK
# ...

# %%
mydf = pd.read_csv('/content/drive/My Drive/USAll.csv', nrows=10)

# %%
mydf
# Out:
#    General Record Type  General Resident status  \
# 0                    2                        2
# 1                    1                        1
# 2                    1                        1
# 3                    1                        1
# 4                    1                        1
# 5                    1                        1
# 6                    1                        1
# 7                    1                        1
# 8                    1                        1
# 9                    1                        1
#
#    General Place of death and decedents status  General Day of week of death  \
# 0                                            6                             6
# 1                                            4                             1
# 2                                            4                             1
# 3                                            4                             6
# ...
